# %%
import pandas as pd

# as?
# 별칭(별명)

# %%
# 데이터프레임으로 만들 데이터 생성
data = {
    # 열 내부의 데이터 타입은 동일하다.
    "name": ["민수", "지연", "현우"],
    "age": [16, 19, 20.5],
}

# Pandas의 데이터프레임 객체 생성
df = pd.DataFrame(data)
# df -> dataframe

print(df)
# Out:
#   name   age
# 0   민수  16.0
# 1   지연  19.0
# 2   현우  20.5

# %%
# 리스트 활용 데이터프레임 생성 코드
data = [
    {"name": "민수", "age": 16},
    {"name": "지연", "age": 18},
    {"name": "현우", "age": 19},
    {"name": "수진", "age": 16, "location": "서울"},
]

df = pd.DataFrame(data)
print(df)

# none 없다
# NaN 없다. 결측치
# Out:
#   name  age location
# 0   민수   16      NaN
# 1   지연   18      NaN
# 2   현우   19      NaN
# 3   수진   16       서울

# %%
data = [
    {
        "name": "Jay",
        "age": 28,
        "salary": 50000,
    },
    {"name": "Anna", "age": 34, "salary": 62000},
]
df = pd.DataFrame(data)

# %%
# 1. Details API 요청해서 영화 정보를 저장한다.
# movie_id = 912649
# 2. 영화 정보를 가지고, data 변수를 생성한다.
# 필요 데이터는
# id, overview, title, release_date
# 3. data 변수로 데이터프레임을 생성한다.

import requests
from pprint import pprint

api_token = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3YmY4ZjNlNDVmZDIzNWZkOTljMjA4YjYxZGNmZGVjYSIsIm5iZiI6MTU2ODg3Njk5MS4wMSwic3ViIjoiNWQ4MzI5YmYxNjJiYzMwMjI3ZGRmY2Q2Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.iBc4VQRVQSZxYEynfP254OHkvSyZNxD0w9I-ge6jJQw"
base_url = "https://api.themoviedb.org/3"
movie_id = "912649"
endpoint = f"/movie/{movie_id}"
request_url = base_url + endpoint
params = {"language": "ko-KR"}
headers = {
    "Authorization": f"Bearer {api_token}",
}
response = requests.get(request_url, headers=headers, params=params).json()
# print(type(response))
# pprint(response)

# 우리가 필요한 데이터
# id, overview, title, release_date
id = response["id"]
overview = response["overview"]
title = response["title"]
release_date = response["release_date"]
# print(id, overview, title, release_date)

data = [
    {
        "id": id,
        "overviwe": overview,
        "title": title,
        "release_date": release_date,
    }
]

print(type(data))
pprint(data)
df = pd.DataFrame(data)
df
# Out:
# <class 'list'>
# [{'id': 912649,
#   'overviwe': '환상의 케미스트리의 에디 브록과 그의 심비오트 베놈은 그들을 노리는 정체불명 존재의 추격을 피해 같이 도망을 '
#               '다니게 된다. 한편 베놈의 창조자 널은 고향 행성에서부터 그들을 찾아내기 위해 지구를 침략하고 에디와 베놈은 '
#               '그동안 겪어보지 못한 최악의 위기를 맞이하게 되는데…',
#   'release_date': '2024-10-22',
#   'title': '베놈: 라스트 댄스'}]
#        id                                           overviwe       title  \
# 0  912649  환상의 케미스트리의 에디 브록과 그의 심비오트 베놈은 그들을 노리는 정체불명 존재의...  베놈: 라스트 댄스
#
#   release_date
# 0   2024-10-22

# %%
import requests
from pprint import pprint

api_token = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3YmY4ZjNlNDVmZDIzNWZkOTljMjA4YjYxZGNmZGVjYSIsIm5iZiI6MTU2ODg3Njk5MS4wMSwic3ViIjoiNWQ4MzI5YmYxNjJiYzMwMjI3ZGRmY2Q2Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.iBc4VQRVQSZxYEynfP254OHkvSyZNxD0w9I-ge6jJQw"
base_url = "https://api.themoviedb.org/3"

endpoint = f"/movie/now_playing"
request_url = base_url + endpoint
params = {"language": "ko-KR"}
headers = {
    "Authorization": f"Bearer {api_token}",
}
response = requests.get(request_url, headers=headers, params=params).json()
movie_list = response["results"]
# print(type(movie_list))
# pprint(movie_list)
"""
data = [
    {
        "id": id,
        "overviwe": overview,
        "title": title,
        "release_date": release_date,
    }
]
"""
# 개별 영화 정보를 저장할 리스트
# 즉, 데이터프레임의 기반 데이터가 될 리스트
data = []
for movie in movie_list:
    # print(movie)
    # 개별 영화 정보에서 필요한 데이터만 추출하는 과정
    id = movie["id"]
    overview = movie["overview"]
    title = movie["title"]
    release_date = movie["release_date"]

    # 개별 영화 정보를 쌓는 과정
    data.append(
        {
            "id": id,
            "overviwe": overview,
            "title": title,
            "release_date": release_date,
        }
    )

# print(len(data))
df = pd.DataFrame(data)
df
# Out:
#          id                                           overviwe  \
# 0    845781  크리스마스 D-1, 철통같은 보안을 뚫고 코드명 '레드 원' 산타클로스가 납치되고 ...
# 1    939243
# 2    762509  길을 잃고 혼자가 된 새끼 사자 무파사는 광활한 야생을 떠돌던 중 왕의 혈통이자 예...
# 3   1241982  바다를 누볐던 선조들에게서 예기치 못한 부름을 받은 모아나가 마우이와 다시 만나 새...
# 4   1005331  크리스마스이브, 항공기에 위험한 물건을 실으라는 강요를 받은 공항 보안 요원. 이 ...
# 5    558449  로마의 영웅이자 최고의 검투사였던 막시무스가 콜로세움에서 죽음을 맞이한 뒤 20여 ...
# 6   1156593  전 세계적인 히트작 '나의 잘못'의 속편. 노아와 닉의 사랑은 둘을 떼어놓으려는 부...
# 7   1043905  2021년 미국의 아프가니스탄 철군 당시, 의료 구호 팀으로 위장한 여성 군인들이 ...
# 8   1035048  한 명의 싱글파더와 두 명의 여성이 어린 소년의 생명을 구하기 위해 집이라는 안전한...
# 9    974453
# 10   539972  죽음의 문턱에서 맹수의 초인적인 힘을 얻고 살아 돌아온 크레이븐이 무자비한 복수의 ...
# 11  1034541  "아트 더 클라운"이 크리스마스 이브에 평화롭게 잠든 "마일스 카운티"의 주민들을 ...
# 12  1064213  뉴욕의 스트리퍼 ‘아노라’는 자신의 바를 찾은 철부지 러시아 재벌2세 ‘이반’을 만...
# 13   645757  역사상 최악의 눈보라가 산타클로스를 포함한 모두의 계획을 틀어지게 한 그날. 웰링턴...
# 14   933260  더 나은 버전의 당신을 꿈꿔본 적 있나요? 당신의 인생을 바꿔줄 신제품 ‘서브스턴스...
# 15  1182387
# ...

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# pandas_practice(현재 폴더) 폴더 안에
# a 폴더를 생성하고,
# a 폴더에 winequality-red.csv 파일을 이동

df = pd.read_csv("../datas/winequality-red.csv")
df = pd.read_csv("./a/winequality-red.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 7
#       1 import pandas as pd
#       3 # pandas_practice(현재 폴더) 폴더 안에
#       4 # a 폴더를 생성하고,
#       5 # a 폴더에 winequality-red.csv 파일을 이동
# ----> 7 df = pd.read_csv("../datas/winequality-red.csv")
#       8 df = pd.read_csv("./a/winequality-red.csv")
#       9 df
#
# ...

# %%
data = [
    {"name": "민수", "age": 16},
    {"name": "지연", "age": 18},
    {"name": "현우", "age": 19},
    {"name": "수진", "age": 16},
]

df = pd.DataFrame(data)
# 저장하고 싶은 데이터프레임.to_파일형식
df.to_csv("example.csv", encoding="cp949")

# %%
import requests
from pprint import pprint

# 오픈 API 서비스키(decording)작성
serviceKey = "z72YeS0RkSO7TS2Va8n0miAZzJ2V6Pi22wRaEtKgxQx9MNukgAVcJUk4hubljQjJi9Zjxob7QVRhH62AwPLjKA=="

# API URL = base_url + endpoint
base_url = "http://apis.data.go.kr/1360000/AirInfoService/"
endpoint = "getAirInfo"

# 요청 URL 조합
request_url = base_url + endpoint

# 요청 파라미터(변수) 설정
icaoCode = "RKSI"  # ICAO 공항 코드 (예: 인천 공항)
pageNo = 1  # 데이터 출력 페이지 번호
numOfRows = 10  # 한 페이지에 출력할 데이터 수
dataType = "JSON"  # 응답 데이터 포맷(형태)


# fctm = 202412160000  # 예측 시간 (YYYYMMDDHHMM 형식)
# 날짜 + 시간을 지정해서 요청해야 하기 때문에 다른 날짜를 추가적으로 보려면 매번 날짜를 변경해줘야 함

fctm_list = [202412160000, 202412160400, 202412160800]
# 데이프레임의 기반이 되는 변수 data
data = []

for fctm in fctm_list:
    print(fctm)

    params = {  # request_url 에 전달
        "serviceKey": serviceKey,
        "pageNo": pageNo,  # 데이터표출 페이지
        "numOfRows": numOfRows,  # 데이터 행
        "dataType": dataType,  # 응답유형
        "icaoCode": icaoCode,  # ICAO 코드
        "fctm": fctm,  # 발표연월일시분
    }

    response = requests.get(request_url, params=params).json()
    response_data = response["response"]["body"]["items"]["item"]

    # pprint(response_data)

    for i in response_data:
        icaoCode = i["icaoCode"]
        qnh = i["qnh"]
        ta = i["ta"]
        wd = i["wd"]
        ws = i["ws"]
        tmFc = i["tmFc"]

        data.append(
            {
                "icaoCode": icaoCode,
                "qnh": qnh,
                "ta": ta,
                "wd": wd,
                "ws": ws,
                "tmFc": tmFc,
                "fctm": fctm,
            }
        )

    import pandas as pd

# csv 파일로 저장
# 13 14 15 16 데이터 -> 데이터프레임 -> 저장
df = pd.DataFrame(data)
df.to_csv("example1.csv", encoding="cp949")
df
# Out:
# 202412160000
# 202412160400
# 202412160800
#    icaoCode   qnh  ta   wd ws          tmFc          fctm
# 0      RKSI  3025  -1  350  5  202412160000  202412160000
# 1      RKSI  3025   1  350  5  202412160100  202412160000
# 2      RKSI  3023   2  360  5  202412160200  202412160000
# 3      RKSI  3020   2  300  5  202412160300  202412160000
# 4      RKSI  3019   3  300  5  202412160400  202412160400
# 5      RKSI  3016   3  250  5  202412160500  202412160400
# 6      RKSI  3016   3  250  5  202412160600  202412160400
# 7      RKSI  3016   3  250  5  202412160700  202412160400
# 8      RKSI  3017   2  250  5  202412160800  202412160800
# 9      RKSI  3017   2   50  5  202412160900  202412160800
# 10     RKSI  3019   1   50  5  202412161000  202412160800
# 11     RKSI  3020   1   30  7  202412161100  202412160800
